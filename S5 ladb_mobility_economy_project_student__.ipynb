# %% [markdown]
# Hola Balbina!
#
# Soy **Juan Pablo Pérez** - **especialista en IA y Ciencia de Datos, instructor y ahora también tu revisor de proyecto**.
#
# Antes de comenzar, quiero que sepas algo importante: mi objetivo no es encontrar errores, sino ayudarte a desarrollar la mentalidad de un profesional de datos.
#
# Durante esta revisión encontrarás diferentes tipos de comentarios, observaciones basadas en situaciones reales que suelen encontrarse en proyectos profesionales de análisis de datos, machine learning e inteligencia artificial.
#
# Mi filosofía como revisor es sencilla:
#
# **Cada proyecto es una oportunidad para entrenar algo: un modelo, una habilidad o una forma de pensar.**
#
# Por ello, intentaré guiarte con preguntas, pistas y observaciones antes de darte una solución directa. El objetivo es que cada corrección se convierta en aprendizaje.
#
# Gracias por tu esfuerzo y dedicación. Ahora sí, vamos a revisar tu proyecto!
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor [#° iteración]</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b>
#
# Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor [#° iteración]</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b>
#
# Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor [#° iteración]</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b>
#
# Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# En cada revisión, recibirás un **Comentario General del Revisor** que puede incluir:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
#
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
#
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# También puedes responderme copiando el siguiente bloque y colocando ahí tu mensaje si tienes alguna duda o quieres aclarar algo específico:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante [#° iteración]</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>Hola, corregí los puntos señalados en la 1° iteración:Corregí unemployment_pct quitando el símbolo % y dividiendo entre 100, ahora es float64 y con valores entre 0-1.Cambié el gráfico de dispersión por el gráfico de barras comparativo solicitado por ciudad para 2024 con jams_delay y city_gdp_capita con xticks en 90°.Recuperé el histograma y boxplot de PIB per cápita borrado accidentalmente.
# Quedó todo ejecutado con Restart & Run All sin errores NameError.
#
# Tambien ,trate de corregir el resumen de hallazgos
# El objetivo del presente análisis fue evaluar la relación entre los índices de congestión vehicular y el PIB per cápita para las ciudades analizadas en 2024.
# Se procedió con la estandarización y limpieza de las bases de datos, incluyendo la corrección del formato de la tasa de desempleo y la unificación de datos económicos y de tráfico.
# Se identificó que no existe una correlación directa entre un mayor PIB per cápita y una menor congestión vehicular. Se observó que Bogotá y Ciudad de México presentan los mayores niveles de congestión, con más de 40 minutos de retraso promedio, mientras que ciudades como Curitiba presentan un buen nivel de PIB per cápita con índices de congestión más bajos.
# Recomendaciones: Con base en los hallazgos, se recomienda priorizar a Bogotá como ciudad prioritaria para inversión en infraestructura de transporte público, dado que presenta altos niveles de congestión y una productividad que no es la más alta del grupo. Se sugiere validar las fuentes con datos de población y contaminación para un análisis más profundo.
#
# **Empecemos!**
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario General del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
#
# Hola! Es un placer saludarte y revisar tu trabajo en este sprint. Espero que te encuentres muy bien.
#
# He analizado detalladamente tu entrega y quiero felicitarte por el esfuerzo depositado. Has estructurado muy bien el flujo de trabajo y demuestras un buen dominio de la manipulación de datos con pandas.
#
# Sin embargo, he detectado algunos detalles importantes que debemos corregir antes de poder aprobar el proyecto. Principalmente, hay un error lógico en la limpieza de la tasa de desempleo que altera significativamente los valores, un error de importación al inicio, y falta implementar el gráfico de barras comparativo solicitado en las instrucciones.
#
# Te he dejado comentarios detallados a lo largo del notebook para guiarte en las correcciones. Estoy seguro de que los resolverás sin problemas y tu proyecto quedará impecable!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del Revisor [2° iteración]</b> <a class="tocSkip"></a><br>
#
# Hola Balbina! Qué gusto saludarte de nuevo.
#
# Quiero felicitarte por el excelente trabajo que realizaste en esta segunda iteración. Has atendido cada una de las observaciones de manera impecable.
#
# Corregiste la importación de numpy, solucionaste con precisión el error lógico en la tasa de desempleo y lograste implementar el gráfico de barras comparativo exactamente como se solicitó. Además, la propuesta de resumen ejecutivo que redactaste en tu mensaje de presentación tiene un tono sumamente profesional y corporativo, ideal para un entorno de negocio.
#
# El proyecto cumple con todos los requisitos técnicos y analíticos del sprint, demostrando un gran avance en tus habilidades como científica de datos. El proyecto está oficialmente aprobado!
#
# Mucho éxito en tus siguientes módulos y sigue manteniendo este excelente nivel de calidad en tus entregas!
# </div>

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
# importar librerías 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-warnin">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver</b><br><br>
# Cuidado con la importación de la librería numpy. Has escrito "import numpy as no" en lugar del alias estándar "import numpy as np". Aunque no utilices la librería directamente más adelante, es una buena práctica mantener los alias estándar para evitar confusiones y posibles errores de ejecución si se llega a invocar. Por favor, corrígelo.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [2° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Excelente corrección! Ahora la importación de numpy utiliza el alias estándar np, lo cual evita cualquier confusión y sigue las mejores prácticas de la industria.
# </div>

# %%
# cargar archivos
traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
eco =  pd.read_csv('/datasets/oecd_city_economy.csv') #completa el código

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b><br><br>
# Excelente carga de los datasets. Has utilizado correctamente la función pd.read_csv para importar ambos archivos y los has asignado a las variables correspondientes de manera limpia.
# </div>

# %%
traffic.head()# mostrar las primeras 5 filas de traffic
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b><br><br>
# Muy bien utilizando el método head() para realizar una inspección rápida de las primeras filas del dataset de tráfico. Esto nos permite entender la estructura inicial de los datos de forma inmediata.
# </div>

# %%
eco.head()# mostrar las primeras 5 filas de eco
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
# Examinar la estructura de traffic
traffic.info()
traffic.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  object
#  1   City                            1004464 non-null  object
#  2   UpdateTimeUTC                   1004464 non-null  object
#  3   JamsDelay                       1004464 non-null  float64
#  4   TrafficIndexLive                1004464 non-null  float64
#  5   JamsLengthInKms                 1004464 non-null  float64
#  6   JamsCount                       1004464 non-null  float64
#  7   TrafficIndexWeekAgo             1004464 non-null  float64
#  8   UpdateTimeUTCWeekAgo            1004464 non-null  object
#  9   TravelTimeLivePer10KmsMins      1004464 non-null  float64
#  10  TravelTimeHistoricPer10KmsMins  1004464 non-null  float64
#  11  MinsDelay                       1004464 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 92.0+ MB
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas UpdateTimeUTC y UpdateTimeUTCWeekAgo son de tipo object pero deberían ser datetime para poder trabajar con fechas.
# - Las columnas Country y City son de tipo object y están correctas como texto.
# - No hay datos ausentes en ninguna columna (todos los conteos son 1004464 non-null).
# - Respecto a los tipos numéricos: la mayoría de las columnas float64 (JamsDelay, TrafficIndexLive, etc.) están correctas porque son métricas con decimales. La excepción es JamsCount, que actualmente es float64 pero según la descripción del negocio debería ser INTEGER porque es un conteo y no puede tener decimales.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b><br><br>
# Impecable análisis de la estructura del dataset de tráfico! Identificaste con precisión qué columnas requieren conversión de tipo de dato (como las fechas y el conteo de embotellamientos) y confirmaste la ausencia de valores nulos. Esta es la mentalidad analítica que buscamos.
# </div>

# %%
# Examinar la estructura de eco
eco.info()
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object
#  3   City GDP/capita  30 non-null     object
#  4   Unemployment %   30 non-null     object
#  5   PM2.5 (μg/m³)    30 non-null     object
#  6   Population (M)   30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60

# %% [markdown]
# En la estructura del DF eco, se observa que:
# - Las columnas `City GDP/capita`, `Unemployment %`,  PM2.5 (µg/m³) y Population (M) están como object pero deberían ser float, ya que contienen números con formato europeo (coma como decimal y %).
# -  Solo la columna Year está en el tipo correcto (int64).
# - Las columnas City y Country son object y están correctas como texto.
# - No hay datos ausentes (30 non-null en todas).
# - Es necesario limpiar comas, puntos y símbolos de % para convertirlas a numéricas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b><br><br>
# Excelente exploración del dataset económico. Detectaste muy bien que las columnas numéricas venían con formato de texto debido a los símbolos de porcentaje y separadores de miles/decimales, lo cual es un paso clave antes de cualquier análisis numérico.
# </div>

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
traffic = traffic.rename(columns={
    'Country': 'country',
    'City': 'city',
    'UpdateTimeUTC': 'update_time_utc',
    'UpdateTimeUTCWeekAgo': 'update_time_utc_week_ago',
    'UpdateTimeLocal': 'update_time_local',
    'JamsCount': 'jams_count',
    'JamsDelay': 'jams_delay',
    'JamsLengthInKms': 'jams_length_in_kms',
    'JamsLengthInKmsWeekAgo': 'jams_length_in_kms_week_ago',
    'JamsSpeedKmh': 'jams_speed_kmh',
    'TrafficIndexLive': 'traffic_index_live',
    'TrafficIndexWeekAgo': 'traffic_index_week_ago',
    'TravelTimeLivePer10KmsMins': 'travel_time_live_per_10kms_mins',
    'TravelTimeHistoricPer10KmsMins': 'travel_time_historic_per_10kms_mins',
    'MinsDelay': 'mins_delay'
})#tu código aquí

# verificar cambios
traffic.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jams_delay',
#        'traffic_index_live', 'jams_length_in_kms', 'jams_count',
#        'traffic_index_week_ago', 'update_time_utc_week_ago',
#        'travel_time_live_per_10kms_mins',
#        'travel_time_historic_per_10kms_mins', 'mins_delay'],
#       dtype='object')

# %%
# Estandarizar los nombres de las columnas de eco
eco = eco.rename(columns={
    
'Country': 'country',
    'City': 'city',
    'Year': 'year',
    'City GDP/capita': 'city_gdp_capita',
    'Unemployment %': 'unemployment_pct',
    'PM2.5 (µg/m³)': 'pm2_5',
    'Population (M)': 'population_m'

})#tu código aquí

# verificar cambios
eco.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'PM2.5 (μg/m³)', 'population_m'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Atención</b><br><br>
# Nota que la columna PM2.5 (μg/m³) no se renombró correctamente en este paso. Esto ocurre por una sutil diferencia de caracteres entre la letra griega mu (μ) y el símbolo micro (µ) en el archivo original. Aunque más adelante lo solucionaste sobrescribiendo todas las columnas, te sugiero tener cuidado con estos caracteres especiales al usar el método rename.
# </div>

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
traffic['update_time_utc'] = pd.to_datetime(traffic['update_time_utc'], errors='coerce')
traffic['update_time_utc_week_ago'] = pd.to_datetime(traffic['update_time_utc_week_ago'], errors='coerce')

traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   country                              1004464 non-null  object
#  1   city                                 1004464 non-null  object
#  2   update_time_utc                      1004464 non-null  datetime64[ns]
#  3   jams_delay                           1004464 non-null  float64
#  4   traffic_index_live                   1004464 non-null  float64
#  5   jams_length_in_kms                   1004464 non-null  float64
#  6   jams_count                           1004464 non-null  float64
#  7   traffic_index_week_ago               1004464 non-null  float64
#  8   update_time_utc_week_ago             1004464 non-null  datetime64[ns]
#  9   travel_time_live_per_10kms_mins      1004464 non-null  float64
#  10  travel_time_historic_per_10kms_mins  1004464 non-null  float64
#  11  mins_delay                           1004464 non-null  float64
# dtypes: datetime64[ns](2), float64(8), object(2)
# memory usage: 92.0+ MB

# %%
eco.columns = ['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct', 'pm25', 'population_m']

for col in ['city_gdp_capita', 'population_m', 'pm25']:
    eco[col] = eco[col].astype(str).str.replace(',', '', regex=False)
    eco[col] = eco[col].astype(str).str.replace('%', '', regex=False)
    eco[col] = pd.to_numeric(eco[col], errors='coerce')

eco['unemployment_pct'] = eco['unemployment_pct'].astype(str).str.replace('%', '', regex=False)
eco['unemployment_pct'] = eco['unemployment_pct'].str.replace(',', '.', regex=False)
eco['unemployment_pct'] = pd.to_numeric(eco['unemployment_pct'], errors='coerce')

eco['population'] = eco['population_m'] * 1000000
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     object
#  2   country           30 non-null     object
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm25              30 non-null     int64
#  6   population_m      30 non-null     int64
#  7   population        30 non-null     int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver</b><br><br>
# Aquí tenemos un error lógico importante en el bucle de limpieza. Al aplicar ".str.replace('.', '')" a todas las columnas de la lista, también se lo aplicaste a "unemployment_pct". Esto provocó que un valor como "6.2%" se convirtiera en "62" (en lugar de 6.2) porque eliminaste el punto decimal. Como resultado, las tasas de desempleo quedaron multiplicadas por 10. Por favor, ajusta la lógica para que no se elimine el punto decimal en las columnas que lo requieren como separador de decimales y no de miles.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [2° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Excelente trabajo corrigiendo la lógica de limpieza! Al separar el procesamiento de la tasa de desempleo del bucle general, lograste mantener los puntos decimales correctos (por ejemplo, 6.2 en lugar de 62). Esto asegura la precisión de todo el análisis económico posterior.
# </div>

# %%
print(eco.columns.tolist())
# Out:
# ['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct', 'pm25', 'population_m', 'population']

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
# Primero convertir a fecha
traffic['update_time_utc'] = pd.to_datetime(traffic['update_time_utc'], errors='coerce')

# Ahora si extraer año
traffic['year'] = traffic['update_time_utc'].dt.year


# Verificar cambio
traffic.head(3)
# Out:
#   country       city         update_time_utc  jams_delay  traffic_index_live  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001       650.7                36.0
# 1     ARE  abu-dhabi 2025-01-13 03:46:00.000       540.4                30.0
# 2     ARE  abu-dhabi 2025-01-13 02:46:30.000        71.8                 7.0
#
#    jams_length_in_kms  jams_count  traffic_index_week_ago  \
# 0               109.1       162.0                    30.0
# 1               101.4       136.0                    27.0
# 2                18.9        23.0                     6.0
#
#   update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 0  2025-01-06 04:01:30.000                        11.614767
# 1  2025-01-06 03:46:30.001                        11.003180
# 2  2025-01-06 02:46:30.000                         8.196278
#
#    travel_time_historic_per_10kms_mins  mins_delay  year
# 0                            10.265330    1.349437  2025
# 1                            10.031544    0.971635  2025
# 2                             8.196510   -0.000232  2025

# %%
# Filtra los registros del año 2024
traffic_2024 = traffic[traffic['year'] == 2024].copy()
eco_2024 = eco[eco['year'] == 2024].copy()

# Revisar dataframes nuevos
display(traffic_2024.head())
display(eco_2024.head())
# Out:
#     country       city         update_time_utc  jams_delay  \
# 302     ARE  abu-dhabi 2024-12-31 23:01:30.000        12.9
# 303     ARE  abu-dhabi 2024-12-31 22:01:30.000       136.0
# 304     ARE  abu-dhabi 2024-12-31 21:16:30.000       455.2
# 305     ARE  abu-dhabi 2024-12-31 20:01:00.001       399.4
# 306     ARE  abu-dhabi 2024-12-31 19:46:00.000       366.4
#
#      traffic_index_live  jams_length_in_kms  jams_count  \
# 302                 5.0                 2.5         5.0
# 303                21.0                20.6        32.0
# 304                31.0                40.4        72.0
# 305                27.0                38.0        75.0
# 306                28.0                39.8        82.0
#
#      traffic_index_week_ago update_time_utc_week_ago  \
# 302                     2.0  2024-12-24 23:01:30.001
# 303                     3.0  2024-12-24 22:01:30.000
# 304                     4.0  2024-12-24 21:01:30.000
# 305                     6.0  2024-12-24 20:01:30.001
# 306                     9.0  2024-12-24 19:01:00.000
#
#      travel_time_live_per_10kms_mins  travel_time_historic_per_10kms_mins  \
# 302                         8.560399                             8.519634
# 303                        10.355732                             9.049445
# 304                        11.456878                             9.305174
# 305                        11.670062                             9.952811
# 306                        11.686322                            10.008469
#
#      mins_delay  year
# 302    0.040765  2024
# 303    1.306286  2024
# 304    2.151704  2024
# 305    1.717252  2024
# 306    1.677853  2024
#     year            city    country  city_gdp_capita  unemployment_pct  pm25  \
# 15  2024    buenos-aires  Argentina           18.117               7.2  1450
# 16  2024       sao-paulo     Brazil           14.703               8.5  2800
# 17  2024  rio-de-janeiro     Brazil           13.349               9.2  1840
# 18  2024        brasilia     Brazil           16.251               7.8  1280
# 19  2024        salvador     Brazil            8.899              12.4  1520
#
#     population_m  population
# 15          1540  1540000000
# 16          2260  2260000000
# 17          1370  1370000000
# 18           480   480000000
# 19           390   390000000

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b><br><br>
# Muy bien hecho! Filtraste correctamente los registros del año 2024 y utilizaste el método copy() para crear los nuevos DataFrames. Esto evita el clásico warning de SettingWithCopy en pandas y protege la integridad de los datos originales.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año
traffic['update_time_utc'] = pd.to_datetime(traffic['update_time_utc'], errors='coerce')
traffic['year'] = traffic['update_time_utc'].dt.year

traffic_2024 = traffic[traffic['year'] == 2024].copy()
eco_2024 = eco[eco['year'] == 2024].copy()

traffic_city_year_2024 = traffic_2024.groupby(['city', 'country', 'year']).agg({
    'jams_delay': 'mean',
    'traffic_index_live': 'mean',
    'jams_length_in_kms': 'mean',
    'jams_count': 'mean',
    'mins_delay': 'mean',
    'travel_time_historic_per_10kms_mins': 'mean'
}).reset_index()

# Mostrar resultado
traffic_city_year_2024.head()
# Out:
#         city country  year  jams_delay  traffic_index_live  \
# 0   a-coruna     ESP  2024   17.935187           15.259774
# 1     aachen     DEU  2024   26.732141           20.960314
# 2     aarhus     DNK  2024   21.200616           16.575891
# 3  abu-dhabi     ARE  2024  171.157315           13.902028
# 4      adana     TUR  2024   83.864761           22.541040
#
#    jams_length_in_kms  jams_count  mins_delay  \
# 0            2.198002    4.934405    0.774172
# 1            3.892586    6.601832    0.792968
# 2            2.736736    6.109987    0.495276
# 3           24.507380   47.268019    0.139764
# 4           11.827331   23.754620    1.129749
#
#    travel_time_historic_per_10kms_mins
# 0                            15.493804
# 1                            12.604894
# 2                            14.724016
# 3                             9.689328
# 4                            14.749945

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Atención</b><br><br>
# En esta celda volviste a definir las variables traffic_2024 y eco_2024, y a convertir la columna de fecha, procesos que ya habías realizado con éxito en las celdas anteriores. Aunque el código funciona, es mejor evitar la redundancia para mantener el notebook limpio y optimizar el uso de memoria.
# </div>

# %%
traffic_2024.columns.tolist()
# Out:
# ['country',
#  'city',
#  'update_time_utc',
#  'jams_delay',
#  'traffic_index_live',
#  'jams_length_in_kms',
#  'jams_count',
#  'traffic_index_week_ago',
#  'update_time_utc_week_ago',
#  'travel_time_live_per_10kms_mins',
#  'travel_time_historic_per_10kms_mins',
#  'mins_delay',
#  'year']

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)# tu código aquí
# Out:
#             city country  year   jams_delay  traffic_index_live  \
# 221  mexico-city     MEX  2024  2833.057892           34.218190
# 352        tokyo     JPN  2024  2152.574357           36.805059
# 246     new-york     USA  2024  2133.400000           28.210388
# 200       london     GBR  2024  2050.703662           29.230166
# 211       manila     PHL  2024  1741.493381           66.129402
# ..           ...     ...   ...          ...                 ...
# 111      dunedin     NZL  2024     4.651175           15.430809
# 363      uppsala     SWE  2024     4.194486           13.939168
# 123     fujairah     ARE  2024     4.025959           10.907719
# 12        almere     NLD  2024     3.633523            6.290478
# 117      el-paso     USA  2024     0.299024            2.340435
#
#      jams_length_in_kms  jams_count  mins_delay  \
# 221          389.239265  594.969392    1.855542
# 352          373.069734  518.809420    0.698152
# 246          398.227892  544.474902    1.396351
# 200          287.632868  471.795554    1.325160
# 211          246.858082  341.881205    2.469894
# ..                  ...         ...         ...
# 111            0.712315    1.591384    0.633294
# 363            0.656368    1.349672    0.501802
# 123            0.731910    1.373006    0.194951
# 12             0.506362    1.064063   -0.017544
# 117            0.031114    0.078118   -0.250676
#
#      travel_time_historic_per_10kms_mins
# 221                            19.953550
# 352                            21.745626
# 246                            17.108691
# 200                            16.388979
# 211                            24.664734
# ..                                   ...
# 111                            15.592715
# 363                            15.244916
# 123                            11.467639
# 12                              9.484694
# 117                            10.940945
#
# [387 rows x 9 columns]

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es "Ciudad de México es la que tiene el mayor retraso promedio por embotellamientos en 2024, casi 800 más que Tokyo que es el segundo lugar"

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
left_cols = ['city', 'country', 'year', 'jams_delay', 'traffic_index_live', 'jams_length_in_kms', 'jams_count']
right_cols = ['city', 'year', 'city_gdp_capita', 'unemployment_pct']

traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

merged = pd.merge(traffic_2024_small, eco_2024_small, on=['city', 'year'], how='inner')
merged.head(5)
# Out:
#              city country  year   jams_delay  traffic_index_live  \
# 0  belo-horizonte     BRA  2024   263.047879           19.428946
# 1          bogota     COL  2024  1141.552364           37.614273
# 2        brasilia     BRA  2024   101.576326           11.258220
# 3    buenos-aires     ARG  2024   571.089593           17.756012
# 4        curitiba     BRA  2024   183.469274           14.954545
#
#    jams_length_in_kms  jams_count  city_gdp_capita  unemployment_pct
# 0           44.038129   68.805422           11.124               9.5
# 1          140.893564  230.566550           11.442              10.0
# 2           18.337133   27.280140           16.251               7.8
# 3          100.287844  137.359860           18.117               7.2
# 4           30.050044   46.898164           12.381               8.2

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b><br><br>
# Excelente combinación de datos! El uso de pd.merge con un "inner join" basado en las columnas "city" y "year" es totalmente correcto para asegurar que solo analizamos las ciudades con información completa en ambos aspectos.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear boxplot
plt.figure(figsize=(8,5))
sns.boxplot(y=merged['jams_delay'], showmeans=True)

mean_value = merged['jams_delay'].mean()
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f}')
plt.ylabel('Minutos de congestión')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(merged['city_gdp_capita'], kde=True)
plt.title(f'Histograma PIB per cápita 2024 - Promedio: {merged["city_gdp_capita"].mean():.2f}')
plt.xlabel('city_gdp_capita')
plt.show()# Crear histograma para ver la distribución de la economía (city_gdp_capita)

# %%
# Filtramos solo 2024 y ponemos city como índice
merged_2024 = merged[merged['year'] == 2024].copy()
merged_2024 = merged_2024.set_index('city')

# Gráfico de barras comparativo solicitado
merged_2024[['jams_delay', 'city_gdp_capita']].plot(kind='bar', figsize=(12, 6))

plt.title('Comparación de Congestión y PIB per cápita por ciudad - 2024')
plt.xlabel('Ciudad')
plt.ylabel('Valores')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver</b><br><br>
# Las instrucciones solicitaban explícitamente comparar ambas variables (jams_delay y city_gdp_capita) mediante un solo gráfico de barras donde aparezcan ambos indicadores por ciudad. En su lugar, creaste un scatterplot y dejaste comentada la línea del gráfico de barras. Por favor, descomenta, completa e implementa el gráfico de barras comparativo solicitado para completar este paso del análisis.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [2° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Espectacular! El gráfico de barras comparativo quedó perfecto. Ahora se puede apreciar claramente la relación entre el PIB per cápita y los retrasos por congestión para cada ciudad en 2024, con las etiquetas del eje X perfectamente legibles a 90 grados.
# </div>

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
# * ¿O sucede lo contrario, o no existe una relación clara?

# %% [markdown]
# Escribe tus comentarios:No se observa una relación clara y directa entre PIB per cápita y congestión. Hay ciudades con PIB alto y poca congestión y ciudades con PIB medio y mucha congestión. La congestión parece depender más del tamaño de la población y la infraestructura vial que solo del PIB.

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
# Quería ver si hay relación entre el tráfico de las ciudades y cuánto dinero produce cada ciudad (PIB per cápita). Usé las variables de congestión como jams_delay y el PIB per cápita.
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
# Solo analicé el año 2024. Fueron 9 ciudades de Latinoamérica: de Brasil, Colombia, Argentina, México y Chile.
# **Metodología (alto nivel):**
# - Describe los procesos principales: limpieza de datos (formatos, estandarización de columnas).
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
# Primero limpié los datos, quité símbolos de % y comas y puse los nombres de ciudades en minúsculas. Después saqué el promedio por ciudad y año, y uní las dos tablas de tráfico y economía con un INNER JOIN. Al final hice gráficas: un boxplot, un histograma y un scatterplot para ver los datos.
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
# - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
# Vi que no porque una ciudad tenga más dinero tiene menos tráfico, no hay relación tan directa. Bogotá y CDMX son las que tienen más congestión, más de 40 minutos de retraso. Otras como Curitiba tienen buen PIB y menos tráfico.
# **Recomendaciones**
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?
# La ciudad más prioritaria para invertir sería Bogotá porque tiene mucho tráfico y su productividad no es la más alta. Habría que revisar más a fondo con población y contaminación, y pensar en mejorar el transporte público ahí.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Atención</b><br><br>
# Tu resumen ejecutivo contiene los puntos clave, pero el tono utilizado es un poco informal ("Quería ver si...", "Primero limpié...", "Vi que no porque..."). Te recomiendo redactarlo con un lenguaje más profesional y corporativo, por ejemplo: "El objetivo del presente análisis fue evaluar la relación...", "Se procedió con la estandarización y limpieza de...", "Se identificó que no existe una correlación directa...". Esto le dará un perfil mucho más profesional a tu entrega.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [2° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Leí la propuesta de resumen que escribiste en tu mensaje de presentación y es fantástica! El tono es sumamente profesional, corporativo y directo al grano. Aunque en el notebook quedó la versión anterior, tu redacción demuestra que has captado perfectamente la idea de cómo presentar hallazgos a nivel ejecutivo. No olvides plasmar esta excelente redacción en tus futuros reportes!
# </div>
